# %%
import pandas as pd
import collections
from typing import Callable
import datetime

# %%
def calculate_mature_shares(path: str, id: str, logger: Callable[[str], None]) -> float:
    report = pd.read_csv(path, skipfooter=1, parse_dates=True, engine='python')
    logger(f"{len(report)=}")
    report = report.drop(columns=['Activity Date', 'Process Date', 'Description'])
    report = report.loc[report['Instrument'] == id]
    print(report['Trans Code'].unique())
    report = report.loc[report['Trans Code'].isin(["Buy", "Sell"])]
    logger(f"{len(report)=}")
    report['Settle Date'] = pd.to_datetime(report['Settle Date'])
    report = report.sort_values(by='Settle Date')
    logger(report.head(20))
    fifo = collections.deque()
    print("===")
    
    class Record:
        def __init__(self, date: datetime.datetime, quantity: float) -> None:
            self.date = date
            self.quantity = quantity


    for idx, record in report.iterrows():
        date, stock_id, code, quantity, price, amount = record
        if code == "Buy":
            fifo.append(Record(date.to_pydatetime(), float(quantity)))
        if code == "Sell":
            sell_quantity = float(quantity)
            while sell_quantity > 0:
                if len(fifo) > 0:
                    earliest_buy = fifo.popleft()
                    earliest_buy.quantity -= sell_quantity
                    if earliest_buy.quantity > 0:
                        fifo.appendleft(earliest_buy)
                    else:
                        sell_quantity = abs(earliest_buy.quantity)
                else:
                    print("Error: not enough stock to sell. Skip")
                    sell_quantity = 0
    print(fifo)

    mature_quantity = 0
    one_year = datetime.timedelta(days=365)
    current_date = datetime.datetime.combine(datetime.date.today(), datetime.datetime.min.time())
    while len(fifo) > 0:
        earliest_buy = fifo.popleft()
        holding_time = current_date - earliest_buy.date
        print(f"Compare {current_date=} and {earliest_buy.date=}, {holding_time=}")
        if holding_time > one_year:
            print("More than a year")
            mature_quantity += earliest_buy.quantity
        else:
            print("Less than a year")

    return mature_quantity

def notebook_print(log: str) -> None:
    print(log)

calculate_mature_shares("./sample.csv", "VOO", notebook_print)
# Out:
# len(report)=5499
# ['Buy' 'SLIP' 'CDIV' 'Sell']
# len(report)=472
#      Settle Date Instrument Trans Code Quantity    Price       Amount
# 5403  2019-11-29        VOO        Buy        2  $288.28    ($576.56)
# 5352  2020-01-24        VOO        Buy        1  $305.17    ($305.17)
# 5335  2020-02-07        VOO        Buy        2  $305.16    ($610.32)
# 5225  2020-03-11        VOO       Sell        5  $254.28    $1,271.38
# 5177  2020-03-26        VOO        Buy        5  $217.87  ($1,089.35)
# 5133  2020-04-17        VOO       Sell        5  $255.18    $1,275.87
# 5021  2020-04-24        VOO        Buy        5  $256.87  ($1,284.35)
# 5024  2020-04-24        VOO        Buy        5  $256.66  ($1,283.29)
# 5008  2020-04-27        VOO       Sell       10  $256.90    $2,568.94
# 4974  2020-04-28        VOO        Buy        4  $258.08  ($1,032.32)
# 4942  2020-04-28        VOO        Buy       10  $259.34  ($2,593.39)
# 4900  2020-04-30        VOO        Buy        6  $263.68  ($1,582.08)
# 4889  2020-04-30        VOO        Buy        1  $263.47    ($263.47)
# 4780  2020-05-05        VOO       Sell       21  $261.41    $5,489.48
# 4696  2020-05-06        VOO        Buy        6  $258.98  ($1,553.88)
# 4655  2020-05-07        VOO        Buy        4  $262.93  ($1,051.72)
# 4656  2020-05-07        VOO        Buy        2  $263.14    ($526.28)
# 4657  2020-05-07        VOO        Buy        2  $263.12    ($526.24)
# 4659  2020-05-07        VOO        Buy        1  $263.04    ($263.04)
# 4666  2020-05-07        VOO        Buy        2  $264.47    ($528.94)
# ===
# Error: not enough stock to sell. Skip
# Error: not enough stock to sell. Skip
# Error: not enough stock to sell. Skip
# Error: not enough stock to sell. Skip
# deque([<__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710440>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7112b0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf713b00>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710ad0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712e40>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712690>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf711a90>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7106e0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf713d70>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712990>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710920>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf711b80>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712ed0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7107d0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712a50>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7134a0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710110>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf711e20>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7105f0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7115e0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712210>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf711580>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7113a0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf713080>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710170>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7122a0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710f50>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712c90>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf713c80>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7100e0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf711c70>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712fc0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710350>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf713770>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7103b0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7119a0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf710620>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf7121e0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf712bd0>, <__main__.calculate_mature_shares.<locals>.Record object at 0x7f3abf713980>])
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 9, 6, 0, 0), holding_time=datetime.timedelta(days=310)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 9, 14, 0, 0), holding_time=datetime.timedelta(days=302)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 9, 14, 0, 0), holding_time=datetime.timedelta(days=302)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 9, 25, 0, 0), holding_time=datetime.timedelta(days=291)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 9, 28, 0, 0), holding_time=datetime.timedelta(days=288)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 9, 28, 0, 0), holding_time=datetime.timedelta(days=288)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 10, 3, 0, 0), holding_time=datetime.timedelta(days=283)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 10, 5, 0, 0), holding_time=datetime.timedelta(days=281)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 11, 16, 0, 0), holding_time=datetime.timedelta(days=239)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 11, 20, 0, 0), holding_time=datetime.timedelta(days=235)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 11, 24, 0, 0), holding_time=datetime.timedelta(days=231)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 4, 0, 0), holding_time=datetime.timedelta(days=221)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 6, 0, 0), holding_time=datetime.timedelta(days=219)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 7, 0, 0), holding_time=datetime.timedelta(days=218)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 7, 0, 0), holding_time=datetime.timedelta(days=218)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 8, 0, 0), holding_time=datetime.timedelta(days=217)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 8, 0, 0), holding_time=datetime.timedelta(days=217)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 8, 0, 0), holding_time=datetime.timedelta(days=217)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 8, 0, 0), holding_time=datetime.timedelta(days=217)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2023, 12, 22, 0, 0), holding_time=datetime.timedelta(days=203)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 4, 0, 0), holding_time=datetime.timedelta(days=190)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 5, 0, 0), holding_time=datetime.timedelta(days=189)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 5, 0, 0), holding_time=datetime.timedelta(days=189)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 5, 0, 0), holding_time=datetime.timedelta(days=189)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 8, 0, 0), holding_time=datetime.timedelta(days=186)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 11, 0, 0), holding_time=datetime.timedelta(days=183)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 1, 24, 0, 0), holding_time=datetime.timedelta(days=170)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 4, 4, 0, 0), holding_time=datetime.timedelta(days=99)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 4, 4, 0, 0), holding_time=datetime.timedelta(days=99)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 4, 17, 0, 0), holding_time=datetime.timedelta(days=86)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 4, 18, 0, 0), holding_time=datetime.timedelta(days=85)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 5, 17, 0, 0), holding_time=datetime.timedelta(days=56)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 5, 24, 0, 0), holding_time=datetime.timedelta(days=49)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 5, 30, 0, 0), holding_time=datetime.timedelta(days=43)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 6, 6, 0, 0), holding_time=datetime.timedelta(days=36)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 6, 13, 0, 0), holding_time=datetime.timedelta(days=29)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 6, 21, 0, 0), holding_time=datetime.timedelta(days=21)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 6, 27, 0, 0), holding_time=datetime.timedelta(days=15)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 7, 5, 0, 0), holding_time=datetime.timedelta(days=7)
# Less than a year
# Compare current_date=datetime.datetime(2024, 7, 12, 0, 0) and earliest_buy.date=datetime.datetime(2024, 7, 11, 0, 0), holding_time=datetime.timedelta(days=1)
# Less than a year
# 0
